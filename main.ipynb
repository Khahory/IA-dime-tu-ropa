# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
datos, metadatos = tfds.load('fashion_mnist', as_supervised=True, with_info=True)
# Out:
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to ~\tensorflow_datasets\fashion_mnist\3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling ~\tensorflow_datasets\fashion_mnist\3.0.1.incompleteCFHS3M\fashion_mnist-train.tfrecord*...:   0%|  …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling ~\tensorflow_datasets\fashion_mnist\3.0.1.incompleteCFHS3M\fashion_mnist-test.tfrecord*...:   0%|   …
# Dataset fashion_mnist downloaded and prepared to ~\tensorflow_datasets\fashion_mnist\3.0.1. Subsequent calls will reuse this data.

# %%
metadatos
# Out:
# tfds.core.DatasetInfo(
#     name='fashion_mnist',
#     full_name='fashion_mnist/3.0.1',
#     description="""
#     Fashion-MNIST is a dataset of Zalando's article images consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes.
#     """,
#     homepage='https://github.com/zalandoresearch/fashion-mnist',
#     data_path='~\\tensorflow_datasets\\fashion_mnist\\3.0.1',
#     file_format=tfrecord,
#     download_size=29.45 MiB,
#     dataset_size=36.42 MiB,
#     features=FeaturesDict({
#         'image': Image(shape=(28, 28, 1), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=10000, num_shards=1>,
#         'train': <SplitInfo num_examples=60000, num_shards=1>,
#     },
#     citation="""@article{DBLP:journals/corr/abs-1708-07747,
#       author    = {Han Xiao and
#                    Kashif Rasul and
#                    Roland Vollgraf},
#       title     = {Fashion-MNIST: a Novel Image Dataset for Benchmarking Machine Learning
#                    Algorithms},
#       journal   = {CoRR},
#       volume    = {abs/1708.07747},
#       year      = {2017},
#       url       = {http://arxiv.org/abs/1708.07747},
#       archivePrefix = {arXiv},
#       eprint    = {1708.07747},
#       timestamp = {Mon, 13 Aug 2018 16:47:27 +0200},
#       biburl    = {https://dblp.org/rec/bib/journals/corr/abs-1708-07747},
#       bibsource = {dblp computer science bibliography, https://dblp.org}
#     }""",
# )

# %%
# separamos los datos del dataset que descargmos
datos_entrenamiento, datos_prueba = datos['train'], datos['test']

# %%
# guardamos la categoria
nombres_clases = metadatos.features['label'].names

# %%
nombres_clases
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
#normalizar los datos

def normalizar(imagenes, etiquetas):
    imagenes = tf.cast(imagenes, tf.float32)
    imagenes /= 255 #aqui lo pasa de 0-255 a 0-1
    return imagenes, etiquetas

#normalizar los datos de entrenamiento y pruebas con la funcion que hicimos
datos_entrenamiento = datos_entrenamiento.map(normalizar)
datos_prueba = datos_prueba.map(normalizar)

#agregar a cache (usar memoria en lugar de disco, entrenamiento rapido)
datos_entrenamiento = datos_entrenamiento.cache()
datos_prueba = datos_prueba.cache()

# %%
#mostrar una imagen de los datos de prueba, de momento mostrar la primera
for imagen, etiqueta in  datos_entrenamiento.take(1):
    break
imagen = imagen.numpy().reshape((28,28)) #redimensionar, cosas de tensores lo veremos despues

import matplotlib.pyplot as plt

#dibujar
plt.figure()
plt.imshow(imagen, cmap=plt.cm.binary)
plt.colorbar()
plt.grid(False)
plt.show()

# %%
#podemos tambien ver imagenes con sus etiquetas por joder XD
plt.figure(figsize=(10,10))
for i, (imagen, etiqueta) in enumerate(datos_entrenamiento.take(25)):
    imagen = imagen.numpy().reshape((28,28))
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(imagen, cmap=plt.cm.binary)
    plt.xlabel(nombres_clases[etiqueta])
plt.show()

# %%
#crear modelo

modelo = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28,1)), #1 - blanco y negro
    tf.keras.layers.Dense(50, activation=tf.nn.relu),
    tf.keras.layers.Dense(50, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax), #softmax para redes de clasificacion
])

# %%
#compilar el modelo

modelo.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
#Los numeros de datos en entrenamiento y pruebas (60k y 10k)
num_ej_entrenamiento = metadatos.splits["train"].num_examples
num_ej_pruebas = metadatos.splits["test"].num_examples

# %%
#para que no dure mucho compilando lo haremos por lotes

TAMANO_LOTE = 32

datos_entrenamiento = datos_entrenamiento.repeat().shuffle(num_ej_entrenamiento).batch(TAMANO_LOTE)
datos_prueba = datos_prueba.batch(TAMANO_LOTE)

# %%
import math

#entrenar
historial = modelo.fit(datos_entrenamiento, epochs=5, steps_per_epoch=math.ceil(num_ej_entrenamiento/TAMANO_LOTE))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 3ms/step - loss: 0.5221 - accuracy: 0.8175
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3852 - accuracy: 0.8606
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3487 - accuracy: 0.8749
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3245 - accuracy: 0.8817
# Epoch 5/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3136 - accuracy: 0.8834

# %%
plt.xlabel('# Epoca')
plt.ylabel('Magnitud de perdida')
plt.plot(historial.history['loss'])

# %%
#Pintar una cuadricula con varias predicciones, y marcar si fue correcta (azul) o incorrecta (roja)
import numpy as np

for imagenes_prueba, etiquetas_prueba in datos_prueba.take(1):
  imagenes_prueba = imagenes_prueba.numpy()
  etiquetas_prueba = etiquetas_prueba.numpy()
  predicciones = modelo.predict(imagenes_prueba)

def graficar_imagen(i, arr_predicciones, etiquetas_reales, imagenes):
  arr_predicciones, etiqueta_real, img = arr_predicciones[i], etiquetas_reales[i], imagenes[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img[...,0], cmap=plt.cm.binary)

  etiqueta_prediccion = np.argmax(arr_predicciones)
  if etiqueta_prediccion == etiqueta_real:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(nombres_clases[etiqueta_prediccion],
                                100*np.max(arr_predicciones),
                                nombres_clases[etiqueta_real]),
                                color=color)

def graficar_valor_arreglo(i, arr_predicciones, etiqueta_real):
  arr_predicciones, etiqueta_real = arr_predicciones[i], etiqueta_real[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  grafica = plt.bar(range(10), arr_predicciones, color="#777777")
  plt.ylim([0, 1])
  etiqueta_prediccion = np.argmax(arr_predicciones)

  grafica[etiqueta_prediccion].set_color('red')
  grafica[etiqueta_real].set_color('blue')

filas = 5
columnas = 5
num_imagenes = filas*columnas
plt.figure(figsize=(2*2*columnas, 2*filas))
for i in range(num_imagenes):
  plt.subplot(filas, 2*columnas, 2*i+1)
  graficar_imagen(i, predicciones, etiquetas_prueba, imagenes_prueba)
  plt.subplot(filas, 2*columnas, 2*i+2)
  graficar_valor_arreglo(i, predicciones, etiquetas_prueba)
# Out:
# 1/1 [==============================] - 0s 15ms/step

# %%
#Probar una imagen suelta
imagen = imagenes_prueba[4] #AL ser la variable imagenes_prueba solo tiene lo que se le puso en el bloque anterior heheh
imagen = np.array([imagen])
prediccion = modelo.predict(imagen)

print("Prediccion: " + nombres_clases[np.argmax(prediccion[0])])
# Out:
# 1/1 [==============================] - 0s 59ms/step
# Prediccion: Sandal

# %%
#Exportacion del modelo a h5
modelo.save('modelo_exportado.h5')

# %%
#Instalar tensorflowjs para convertir el h5 a un modelo que pueda cargar tensorflowjs en un explorador
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-3.18.0-py3-none-any.whl (77 kB)
#      ---------------------------------------- 77.5/77.5 KB 1.1 MB/s eta 0:00:00
# Collecting tensorflow-hub<0.13,>=0.7.0
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#      -------------------------------------- 108.8/108.8 KB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow<3,>=2.1.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflowjs) (2.9.1)
# Collecting packaging~=20.9
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      ---------------------------------------- 40.9/40.9 KB ? eta 0:00:00
# Requirement already satisfied: six<2,>=1.12.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflowjs) (1.16.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from packaging~=20.9->tensorflowjs) (3.0.9)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.9.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.7.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.14.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.19.4)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.47.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (14.0.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.23.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (4.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: setuptools in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (58.1.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.9.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.26.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow<3,>=2.1.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (2.9.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (2.1.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (1.26.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kha\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<3,>=2.1.0->tensorflowjs) (3.2.0)
# Installing collected packages: tensorflow-hub, packaging, tensorflowjs
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# Successfully installed packaging-20.9 tensorflow-hub-0.12.0 tensorflowjs-3.18.0
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\kha\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
#Convertir el archivo h5 a formato de tensorflowjs
# !mkdir tfjs_target_dir
# !tensorflowjs_converter --input_format keras modelo_exportado.h5 tfjs_target_dir
# Out:
# 2022-07-16 11:05:34.614973: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-07-16 11:05:34.615028: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
